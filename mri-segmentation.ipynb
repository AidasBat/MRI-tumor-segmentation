# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/brain-tumor-segmentation/images/2664.png
# /kaggle/input/brain-tumor-segmentation/images/2539.png
# /kaggle/input/brain-tumor-segmentation/images/1231.png
# /kaggle/input/brain-tumor-segmentation/images/1017.png
# /kaggle/input/brain-tumor-segmentation/images/2437.png
# /kaggle/input/brain-tumor-segmentation/images/2015.png
# /kaggle/input/brain-tumor-segmentation/images/2300.png
# /kaggle/input/brain-tumor-segmentation/images/2673.png
# /kaggle/input/brain-tumor-segmentation/images/2823.png
# /kaggle/input/brain-tumor-segmentation/images/1522.png
# /kaggle/input/brain-tumor-segmentation/images/2064.png
# /kaggle/input/brain-tumor-segmentation/images/641.png
# /kaggle/input/brain-tumor-segmentation/images/1088.png
# /kaggle/input/brain-tumor-segmentation/images/173.png
# /kaggle/input/brain-tumor-segmentation/images/2851.png
# /kaggle/input/brain-tumor-segmentation/images/2448.png
# /kaggle/input/brain-tumor-segmentation/images/1746.png
# /kaggle/input/brain-tumor-segmentation/images/1958.png
# /kaggle/input/brain-tumor-segmentation/images/1479.png
# /kaggle/input/brain-tumor-segmentation/images/815.png
# /kaggle/input/brain-tumor-segmentation/images/1794.png
# /kaggle/input/brain-tumor-segmentation/images/1727.png
# /kaggle/input/brain-tumor-segmentation/images/1684.png
# /kaggle/input/brain-tumor-segmentation/images/1814.png
# /kaggle/input/brain-tumor-segmentation/images/491.png
# /kaggle/input/brain-tumor-segmentation/images/2982.png
# /kaggle/input/brain-tumor-segmentation/images/2276.png
# /kaggle/input/brain-tumor-segmentation/images/1457.png
# /kaggle/input/brain-tumor-segmentation/images/1924.png
# /kaggle/input/brain-tumor-segmentation/images/1084.png
# /kaggle/input/brain-tumor-segmentation/images/718.png
# /kaggle/input/brain-tumor-segmentation/images/709.png
# /kaggle/input/brain-tumor-segmentation/images/2690.png
# /kaggle/input/brain-tumor-segmentation/images/889.png
# /kaggle/input/brain-tumor-segmentation/images/379.png
# /kaggle/input/brain-tumor-segmentation/images/780.png
# /kaggle/input/brain-tumor-segmentation/images/248.png
# /kaggle/input/brain-tumor-segmentation/images/1680.png
# /kaggle/input/brain-tumor-segmentation/images/1675.png
# /kaggle/input/brain-tumor-segmentation/images/2619.png
# /kaggle/input/brain-tumor-segmentation/images/2273.png
# /kaggle/input/brain-tumor-segmentation/images/94.png
# /kaggle/input/brain-tumor-segmentation/images/2969.png
# /kaggle/input/brain-tumor-segmentation/images/2772.png
# /kaggle/input/brain-tumor-segmentation/images/480.png
# /kaggle/input/brain-tumor-segmentation/images/2256.png
# /kaggle/input/brain-tumor-segmentation/images/1145.png
# /kaggle/input/brain-tumor-segmentation/images/2021.png
# /kaggle/input/brain-tumor-segmentation/images/1944.png
# /kaggle/input/brain-tumor-segmentation/images/236.png
# /kaggle/input/brain-tumor-segmentation/images/1012.png
# /kaggle/input/brain-tumor-segmentation/images/2970.png
# /kaggle/input/brain-tumor-segmentation/images/2518.png
# /kaggle/input/brain-tumor-segmentation/images/2176.png
# /kaggle/input/brain-tumor-segmentation/images/1343.png
# /kaggle/input/brain-tumor-segmentation/images/2347.png
# /kaggle/input/brain-tumor-segmentation/images/771.png
# /kaggle/input/brain-tumor-segmentation/images/2884.png
# /kaggle/input/brain-tumor-segmentation/images/2631.png
# /kaggle/input/brain-tumor-segmentation/images/675.png
# /kaggle/input/brain-tumor-segmentation/images/340.png
# /kaggle/input/brain-tumor-segmentation/images/48.png
# /kaggle/input/brain-tumor-segmentation/images/2525.png
# /kaggle/input/brain-tumor-segmentation/images/3012.png
# /kaggle/input/brain-tumor-segmentation/images/1948.png
# /kaggle/input/brain-tumor-segmentation/images/1878.png
# /kaggle/input/brain-tumor-segmentation/images/2211.png
# /kaggle/input/brain-tumor-segmentation/images/513.png
# /kaggle/input/brain-tumor-segmentation/images/2947.png
# /kaggle/input/brain-tumor-segmentation/images/2976.png
# /kaggle/input/brain-tumor-segmentation/images/1037.png
# /kaggle/input/brain-tumor-segmentation/images/677.png
# /kaggle/input/brain-tumor-segmentation/images/350.png
# /kaggle/input/brain-tumor-segmentation/images/2009.png
# /kaggle/input/brain-tumor-segmentation/images/761.png
# /kaggle/input/brain-tumor-segmentation/images/1258.png
# /kaggle/input/brain-tumor-segmentation/images/2565.png
# /kaggle/input/brain-tumor-segmentation/images/314.png
# /kaggle/input/brain-tumor-segmentation/images/1023.png
# /kaggle/input/brain-tumor-segmentation/images/1337.png
# /kaggle/input/brain-tumor-segmentation/images/655.png
# /kaggle/input/brain-tumor-segmentation/images/227.png
# /kaggle/input/brain-tumor-segmentation/images/762.png
# /kaggle/input/brain-tumor-segmentation/images/2803.png
# /kaggle/input/brain-tumor-segmentation/images/726.png
# /kaggle/input/brain-tumor-segmentation/images/2199.png
# /kaggle/input/brain-tumor-segmentation/images/1630.png
# /kaggle/input/brain-tumor-segmentation/images/2920.png
# /kaggle/input/brain-tumor-segmentation/images/238.png
# /kaggle/input/brain-tumor-segmentation/images/61.png
# /kaggle/input/brain-tumor-segmentation/images/2731.png
# /kaggle/input/brain-tumor-segmentation/images/377.png
# /kaggle/input/brain-tumor-segmentation/images/1961.png
# /kaggle/input/brain-tumor-segmentation/images/1798.png
# /kaggle/input/brain-tumor-segmentation/images/2324.png
# /kaggle/input/brain-tumor-segmentation/images/581.png
# /kaggle/input/brain-tumor-segmentation/images/1782.png
# /kaggle/input/brain-tumor-segmentation/images/222.png
# /kaggle/input/brain-tumor-segmentation/images/330.png
# /kaggle/input/brain-tumor-segmentation/images/2742.png
# /kaggle/input/brain-tumor-segmentation/images/511.png
# /kaggle/input/brain-tumor-segmentation/images/579.png
# /kaggle/input/brain-tumor-segmentation/images/278.png
# /kaggle/input/brain-tumor-segmentation/images/2146.png
# /kaggle/input/brain-tumor-segmentation/images/1863.png
# /kaggle/input/brain-tumor-segmentation/images/927.png
# /kaggle/input/brain-tumor-segmentation/images/303.png
# /kaggle/input/brain-tumor-segmentation/images/37.png
# /kaggle/input/brain-tumor-segmentation/images/231.png
# /kaggle/input/brain-tumor-segmentation/images/1048.png
# /kaggle/input/brain-tumor-segmentation/images/2367.png
# /kaggle/input/brain-tumor-segmentation/images/2559.png
# /kaggle/input/brain-tumor-segmentation/images/645.png
# /kaggle/input/brain-tumor-segmentation/images/2270.png
# /kaggle/input/brain-tumor-segmentation/images/1703.png
# /kaggle/input/brain-tumor-segmentation/images/348.png
# /kaggle/input/brain-tumor-segmentation/images/449.png
# /kaggle/input/brain-tumor-segmentation/images/2718.png
# /kaggle/input/brain-tumor-segmentation/images/2779.png
# /kaggle/input/brain-tumor-segmentation/images/353.png
# /kaggle/input/brain-tumor-segmentation/images/2645.png
# /kaggle/input/brain-tumor-segmentation/images/621.png
# /kaggle/input/brain-tumor-segmentation/images/2134.png
# /kaggle/input/brain-tumor-segmentation/images/1726.png
# /kaggle/input/brain-tumor-segmentation/images/148.png
# /kaggle/input/brain-tumor-segmentation/images/990.png
# /kaggle/input/brain-tumor-segmentation/images/2844.png
# /kaggle/input/brain-tumor-segmentation/images/403.png
# /kaggle/input/brain-tumor-segmentation/images/2661.png
# /kaggle/input/brain-tumor-segmentation/images/1590.png
# /kaggle/input/brain-tumor-segmentation/images/1995.png
# /kaggle/input/brain-tumor-segmentation/images/2121.png
# /kaggle/input/brain-tumor-segmentation/images/1855.png
# /kaggle/input/brain-tumor-segmentation/images/1813.png
# /kaggle/input/brain-tumor-segmentation/images/1000.png
# /kaggle/input/brain-tumor-segmentation/images/2346.png
# /kaggle/input/brain-tumor-segmentation/images/2269.png
# /kaggle/input/brain-tumor-segmentation/images/1604.png
# /kaggle/input/brain-tumor-segmentation/images/352.png
# /kaggle/input/brain-tumor-segmentation/images/2522.png
# /kaggle/input/brain-tumor-segmentation/images/35.png
# /kaggle/input/brain-tumor-segmentation/images/2302.png
# /kaggle/input/brain-tumor-segmentation/images/2030.png
# /kaggle/input/brain-tumor-segmentation/images/232.png
# /kaggle/input/brain-tumor-segmentation/images/817.png
# /kaggle/input/brain-tumor-segmentation/images/1827.png
# /kaggle/input/brain-tumor-segmentation/images/334.png
# /kaggle/input/brain-tumor-segmentation/images/177.png
# /kaggle/input/brain-tumor-segmentation/images/2533.png
# /kaggle/input/brain-tumor-segmentation/images/2637.png
# /kaggle/input/brain-tumor-segmentation/images/2990.png
# /kaggle/input/brain-tumor-segmentation/images/1081.png
# /kaggle/input/brain-tumor-segmentation/images/1780.png
# /kaggle/input/brain-tumor-segmentation/images/1992.png
# /kaggle/input/brain-tumor-segmentation/images/2058.png
# /kaggle/input/brain-tumor-segmentation/images/142.png
# /kaggle/input/brain-tumor-segmentation/images/2365.png
# /kaggle/input/brain-tumor-segmentation/images/834.png
# /kaggle/input/brain-tumor-segmentation/images/3002.png
# /kaggle/input/brain-tumor-segmentation/images/1176.png
# /kaggle/input/brain-tumor-segmentation/images/1914.png
# /kaggle/input/brain-tumor-segmentation/images/754.png
# /kaggle/input/brain-tumor-segmentation/images/407.png
# /kaggle/input/brain-tumor-segmentation/images/3047.png
# /kaggle/input/brain-tumor-segmentation/images/2767.png
# /kaggle/input/brain-tumor-segmentation/images/2978.png
# /kaggle/input/brain-tumor-segmentation/images/104.png
# /kaggle/input/brain-tumor-segmentation/images/2013.png
# /kaggle/input/brain-tumor-segmentation/images/1690.png
# /kaggle/input/brain-tumor-segmentation/images/1413.png
# /kaggle/input/brain-tumor-segmentation/images/384.png
# /kaggle/input/brain-tumor-segmentation/images/2011.png
# /kaggle/input/brain-tumor-segmentation/images/1670.png
# /kaggle/input/brain-tumor-segmentation/images/376.png
# /kaggle/input/brain-tumor-segmentation/images/543.png
# /kaggle/input/brain-tumor-segmentation/images/1312.png
# /kaggle/input/brain-tumor-segmentation/images/737.png
# /kaggle/input/brain-tumor-segmentation/images/1156.png
# /kaggle/input/brain-tumor-segmentation/images/1004.png
# /kaggle/input/brain-tumor-segmentation/images/2069.png
# /kaggle/input/brain-tumor-segmentation/images/2675.png
# /kaggle/input/brain-tumor-segmentation/images/3052.png
# /kaggle/input/brain-tumor-segmentation/images/133.png
# /kaggle/input/brain-tumor-segmentation/images/70.png
# /kaggle/input/brain-tumor-segmentation/images/1754.png
# /kaggle/input/brain-tumor-segmentation/images/1529.png
# /kaggle/input/brain-tumor-segmentation/images/162.png
# /kaggle/input/brain-tumor-segmentation/images/419.png
# /kaggle/input/brain-tumor-segmentation/images/951.png
# /kaggle/input/brain-tumor-segmentation/images/1705.png
# /kaggle/input/brain-tumor-segmentation/images/2169.png
# /kaggle/input/brain-tumor-segmentation/images/2410.png
# /kaggle/input/brain-tumor-segmentation/images/940.png
# /kaggle/input/brain-tumor-segmentation/images/3058.png
# /kaggle/input/brain-tumor-segmentation/images/517.png
# /kaggle/input/brain-tumor-segmentation/images/1032.png
# /kaggle/input/brain-tumor-segmentation/images/398.png
# /kaggle/input/brain-tumor-segmentation/images/634.png
# /kaggle/input/brain-tumor-segmentation/images/1513.png
# /kaggle/input/brain-tumor-segmentation/images/186.png
# /kaggle/input/brain-tumor-segmentation/images/778.png
# /kaggle/input/brain-tumor-segmentation/images/3030.png
# /kaggle/input/brain-tumor-segmentation/images/73.png
# /kaggle/input/brain-tumor-segmentation/images/870.png
# /kaggle/input/brain-tumor-segmentation/images/933.png
# /kaggle/input/brain-tumor-segmentation/images/2741.png
# /kaggle/input/brain-tumor-segmentation/images/2513.png
# /kaggle/input/brain-tumor-segmentation/images/1633.png
# /kaggle/input/brain-tumor-segmentation/images/92.png
# /kaggle/input/brain-tumor-segmentation/images/1328.png
# /kaggle/input/brain-tumor-segmentation/images/2182.png
# /kaggle/input/brain-tumor-segmentation/images/2381.png
# /kaggle/input/brain-tumor-segmentation/images/1989.png
# /kaggle/input/brain-tumor-segmentation/images/542.png
# /kaggle/input/brain-tumor-segmentation/images/2376.png
# /kaggle/input/brain-tumor-segmentation/images/2136.png
# /kaggle/input/brain-tumor-segmentation/images/766.png
# /kaggle/input/brain-tumor-segmentation/images/2003.png
# /kaggle/input/brain-tumor-segmentation/images/315.png
# /kaggle/input/brain-tumor-segmentation/images/436.png
# /kaggle/input/brain-tumor-segmentation/images/359.png
# /kaggle/input/brain-tumor-segmentation/images/261.png
# /kaggle/input/brain-tumor-segmentation/images/1214.png
# /kaggle/input/brain-tumor-segmentation/images/1931.png
# /kaggle/input/brain-tumor-segmentation/images/1673.png
# /kaggle/input/brain-tumor-segmentation/images/2051.png
# /kaggle/input/brain-tumor-segmentation/images/1532.png
# /kaggle/input/brain-tumor-segmentation/images/1820.png
# /kaggle/input/brain-tumor-segmentation/images/2537.png
# /kaggle/input/brain-tumor-segmentation/images/1918.png
# /kaggle/input/brain-tumor-segmentation/images/901.png
# /kaggle/input/brain-tumor-segmentation/images/3061.png
# /kaggle/input/brain-tumor-segmentation/images/1096.png
# /kaggle/input/brain-tumor-segmentation/images/2430.png
# /kaggle/input/brain-tumor-segmentation/images/2829.png
# /kaggle/input/brain-tumor-segmentation/images/2893.png
# /kaggle/input/brain-tumor-segmentation/images/153.png
# /kaggle/input/brain-tumor-segmentation/images/1578.png
# /kaggle/input/brain-tumor-segmentation/images/1954.png
# /kaggle/input/brain-tumor-segmentation/images/1500.png
# /kaggle/input/brain-tumor-segmentation/images/1846.png
# /kaggle/input/brain-tumor-segmentation/images/2462.png
# /kaggle/input/brain-tumor-segmentation/images/1959.png
# /kaggle/input/brain-tumor-segmentation/images/2218.png
# /kaggle/input/brain-tumor-segmentation/images/2902.png
# /kaggle/input/brain-tumor-segmentation/images/2099.png
# /kaggle/input/brain-tumor-segmentation/images/1320.png
# /kaggle/input/brain-tumor-segmentation/images/167.png
# /kaggle/input/brain-tumor-segmentation/images/1348.png
# /kaggle/input/brain-tumor-segmentation/images/2640.png
# /kaggle/input/brain-tumor-segmentation/images/628.png
# /kaggle/input/brain-tumor-segmentation/images/3053.png
# /kaggle/input/brain-tumor-segmentation/images/2041.png
# /kaggle/input/brain-tumor-segmentation/images/506.png
# /kaggle/input/brain-tumor-segmentation/images/2156.png
# /kaggle/input/brain-tumor-segmentation/images/1147.png
# /kaggle/input/brain-tumor-segmentation/images/1375.png
# /kaggle/input/brain-tumor-segmentation/images/1452.png
# /kaggle/input/brain-tumor-segmentation/images/2094.png
# /kaggle/input/brain-tumor-segmentation/images/441.png
# /kaggle/input/brain-tumor-segmentation/images/928.png
# /kaggle/input/brain-tumor-segmentation/images/562.png
# /kaggle/input/brain-tumor-segmentation/images/681.png
# /kaggle/input/brain-tumor-segmentation/images/2668.png
# /kaggle/input/brain-tumor-segmentation/images/2582.png
# /kaggle/input/brain-tumor-segmentation/images/1266.png
# /kaggle/input/brain-tumor-segmentation/images/1542.png
# /kaggle/input/brain-tumor-segmentation/images/2526.png
# /kaggle/input/brain-tumor-segmentation/images/1206.png
# /kaggle/input/brain-tumor-segmentation/images/3028.png
# /kaggle/input/brain-tumor-segmentation/images/1064.png
# /kaggle/input/brain-tumor-segmentation/images/204.png
# /kaggle/input/brain-tumor-segmentation/images/646.png
# /kaggle/input/brain-tumor-segmentation/images/1179.png
# /kaggle/input/brain-tumor-segmentation/images/2233.png
# /kaggle/input/brain-tumor-segmentation/images/75.png
# /kaggle/input/brain-tumor-segmentation/images/1128.png
# /kaggle/input/brain-tumor-segmentation/images/296.png
# /kaggle/input/brain-tumor-segmentation/images/2184.png
# /kaggle/input/brain-tumor-segmentation/images/1494.png
# /kaggle/input/brain-tumor-segmentation/images/2388.png
# /kaggle/input/brain-tumor-segmentation/images/1364.png
# /kaggle/input/brain-tumor-segmentation/images/1334.png
# /kaggle/input/brain-tumor-segmentation/images/1576.png
# /kaggle/input/brain-tumor-segmentation/images/1072.png
# /kaggle/input/brain-tumor-segmentation/images/2832.png
# /kaggle/input/brain-tumor-segmentation/images/1123.png
# /kaggle/input/brain-tumor-segmentation/images/1808.png
# /kaggle/input/brain-tumor-segmentation/images/2801.png
# /kaggle/input/brain-tumor-segmentation/images/744.png
# /kaggle/input/brain-tumor-segmentation/images/2428.png
# /kaggle/input/brain-tumor-segmentation/images/1314.png
# /kaggle/input/brain-tumor-segmentation/images/538.png
# /kaggle/input/brain-tumor-segmentation/images/1301.png
# /kaggle/input/brain-tumor-segmentation/images/651.png
# /kaggle/input/brain-tumor-segmentation/images/899.png
# /kaggle/input/brain-tumor-segmentation/images/1907.png
# /kaggle/input/brain-tumor-segmentation/images/270.png
# /kaggle/input/brain-tumor-segmentation/images/2607.png
# /kaggle/input/brain-tumor-segmentation/images/89.png
# /kaggle/input/brain-tumor-segmentation/images/385.png
# /kaggle/input/brain-tumor-segmentation/images/2096.png
# /kaggle/input/brain-tumor-segmentation/images/768.png
# /kaggle/input/brain-tumor-segmentation/images/872.png
# /kaggle/input/brain-tumor-segmentation/images/2079.png
# /kaggle/input/brain-tumor-segmentation/images/338.png
# /kaggle/input/brain-tumor-segmentation/images/3025.png
# /kaggle/input/brain-tumor-segmentation/images/333.png
# /kaggle/input/brain-tumor-segmentation/images/164.png
# /kaggle/input/brain-tumor-segmentation/images/1168.png
# /kaggle/input/brain-tumor-segmentation/images/1118.png
# /kaggle/input/brain-tumor-segmentation/images/1867.png
# /kaggle/input/brain-tumor-segmentation/images/752.png
# /kaggle/input/brain-tumor-segmentation/images/2795.png
# /kaggle/input/brain-tumor-segmentation/images/550.png
# /kaggle/input/brain-tumor-segmentation/images/1326.png
# /kaggle/input/brain-tumor-segmentation/images/521.png
# /kaggle/input/brain-tumor-segmentation/images/1275.png
# /kaggle/input/brain-tumor-segmentation/images/2355.png
# /kaggle/input/brain-tumor-segmentation/images/2143.png
# /kaggle/input/brain-tumor-segmentation/images/1789.png
# /kaggle/input/brain-tumor-segmentation/images/11.png
# /kaggle/input/brain-tumor-segmentation/images/1668.png
# /kaggle/input/brain-tumor-segmentation/images/1036.png
# /kaggle/input/brain-tumor-segmentation/images/615.png
# /kaggle/input/brain-tumor-segmentation/images/416.png
# /kaggle/input/brain-tumor-segmentation/images/2495.png
# /kaggle/input/brain-tumor-segmentation/images/1952.png
# /kaggle/input/brain-tumor-segmentation/images/994.png
# /kaggle/input/brain-tumor-segmentation/images/881.png
# /kaggle/input/brain-tumor-segmentation/images/605.png
# /kaggle/input/brain-tumor-segmentation/images/707.png
# /kaggle/input/brain-tumor-segmentation/images/2854.png
# /kaggle/input/brain-tumor-segmentation/images/351.png
# /kaggle/input/brain-tumor-segmentation/images/1010.png
# /kaggle/input/brain-tumor-segmentation/images/1910.png
# /kaggle/input/brain-tumor-segmentation/images/1208.png
# /kaggle/input/brain-tumor-segmentation/images/213.png
# /kaggle/input/brain-tumor-segmentation/images/2577.png
# /kaggle/input/brain-tumor-segmentation/images/1695.png
# /kaggle/input/brain-tumor-segmentation/images/411.png
# /kaggle/input/brain-tumor-segmentation/images/2183.png
# /kaggle/input/brain-tumor-segmentation/images/505.png
# /kaggle/input/brain-tumor-segmentation/images/1445.png
# /kaggle/input/brain-tumor-segmentation/images/114.png
# /kaggle/input/brain-tumor-segmentation/images/1698.png
# /kaggle/input/brain-tumor-segmentation/images/1871.png
# /kaggle/input/brain-tumor-segmentation/images/1307.png
# /kaggle/input/brain-tumor-segmentation/images/930.png
# /kaggle/input/brain-tumor-segmentation/images/2278.png
# /kaggle/input/brain-tumor-segmentation/images/302.png
# /kaggle/input/brain-tumor-segmentation/images/185.png
# /kaggle/input/brain-tumor-segmentation/images/1870.png
# /kaggle/input/brain-tumor-segmentation/images/240.png
# /kaggle/input/brain-tumor-segmentation/images/1483.png
# /kaggle/input/brain-tumor-segmentation/images/811.png
# /kaggle/input/brain-tumor-segmentation/images/317.png
# /kaggle/input/brain-tumor-segmentation/images/2653.png
# /kaggle/input/brain-tumor-segmentation/images/1294.png
# /kaggle/input/brain-tumor-segmentation/images/1530.png
# /kaggle/input/brain-tumor-segmentation/images/2026.png
# /kaggle/input/brain-tumor-segmentation/images/1678.png
# /kaggle/input/brain-tumor-segmentation/images/2998.png
# /kaggle/input/brain-tumor-segmentation/images/1514.png
# /kaggle/input/brain-tumor-segmentation/images/1041.png
# /kaggle/input/brain-tumor-segmentation/images/2702.png
# /kaggle/input/brain-tumor-segmentation/images/281.png
# /kaggle/input/brain-tumor-segmentation/images/2901.png
# /kaggle/input/brain-tumor-segmentation/images/344.png
# /kaggle/input/brain-tumor-segmentation/images/1967.png
# /kaggle/input/brain-tumor-segmentation/images/1649.png
# /kaggle/input/brain-tumor-segmentation/images/2519.png
# /kaggle/input/brain-tumor-segmentation/images/1268.png
# /kaggle/input/brain-tumor-segmentation/images/1627.png
# /kaggle/input/brain-tumor-segmentation/images/3056.png
# /kaggle/input/brain-tumor-segmentation/images/457.png
# /kaggle/input/brain-tumor-segmentation/images/493.png
# /kaggle/input/brain-tumor-segmentation/images/1329.png
# /kaggle/input/brain-tumor-segmentation/images/759.png
# /kaggle/input/brain-tumor-segmentation/images/907.png
# /kaggle/input/brain-tumor-segmentation/images/2489.png
# /kaggle/input/brain-tumor-segmentation/images/1071.png
# /kaggle/input/brain-tumor-segmentation/images/362.png
# /kaggle/input/brain-tumor-segmentation/images/2336.png
# /kaggle/input/brain-tumor-segmentation/images/2751.png
# /kaggle/input/brain-tumor-segmentation/images/1148.png
# /kaggle/input/brain-tumor-segmentation/images/176.png
# /kaggle/input/brain-tumor-segmentation/images/2106.png
# /kaggle/input/brain-tumor-segmentation/images/660.png
# /kaggle/input/brain-tumor-segmentation/images/727.png
# /kaggle/input/brain-tumor-segmentation/images/1625.png
# /kaggle/input/brain-tumor-segmentation/images/2088.png
# /kaggle/input/brain-tumor-segmentation/images/95.png
# /kaggle/input/brain-tumor-segmentation/images/2228.png
# /kaggle/input/brain-tumor-segmentation/images/432.png
# /kaggle/input/brain-tumor-segmentation/images/895.png
# /kaggle/input/brain-tumor-segmentation/images/1161.png
# /kaggle/input/brain-tumor-segmentation/images/2594.png
# /kaggle/input/brain-tumor-segmentation/images/97.png
# /kaggle/input/brain-tumor-segmentation/images/1351.png
# /kaggle/input/brain-tumor-segmentation/images/124.png
# /kaggle/input/brain-tumor-segmentation/images/2429.png
# /kaggle/input/brain-tumor-segmentation/images/119.png
# /kaggle/input/brain-tumor-segmentation/images/1227.png
# /kaggle/input/brain-tumor-segmentation/images/2747.png
# /kaggle/input/brain-tumor-segmentation/images/256.png
# /kaggle/input/brain-tumor-segmentation/images/2861.png
# /kaggle/input/brain-tumor-segmentation/images/791.png
# /kaggle/input/brain-tumor-segmentation/images/654.png
# /kaggle/input/brain-tumor-segmentation/images/100.png
# /kaggle/input/brain-tumor-segmentation/images/1381.png
# /kaggle/input/brain-tumor-segmentation/images/211.png
# /kaggle/input/brain-tumor-segmentation/images/1241.png
# /kaggle/input/brain-tumor-segmentation/images/2345.png
# /kaggle/input/brain-tumor-segmentation/images/2696.png
# /kaggle/input/brain-tumor-segmentation/images/500.png
# /kaggle/input/brain-tumor-segmentation/images/2333.png
# /kaggle/input/brain-tumor-segmentation/images/322.png
# /kaggle/input/brain-tumor-segmentation/images/1584.png
# /kaggle/input/brain-tumor-segmentation/images/2372.png
# /kaggle/input/brain-tumor-segmentation/images/1622.png
# /kaggle/input/brain-tumor-segmentation/images/76.png
# /kaggle/input/brain-tumor-segmentation/images/1269.png
# /kaggle/input/brain-tumor-segmentation/images/1197.png
# /kaggle/input/brain-tumor-segmentation/images/193.png
# /kaggle/input/brain-tumor-segmentation/images/2541.png
# /kaggle/input/brain-tumor-segmentation/images/2841.png
# /kaggle/input/brain-tumor-segmentation/images/608.png
# /kaggle/input/brain-tumor-segmentation/images/1893.png
# /kaggle/input/brain-tumor-segmentation/images/1955.png
# /kaggle/input/brain-tumor-segmentation/images/191.png
# /kaggle/input/brain-tumor-segmentation/images/420.png
# /kaggle/input/brain-tumor-segmentation/images/528.png
# /kaggle/input/brain-tumor-segmentation/images/163.png
# /kaggle/input/brain-tumor-segmentation/images/31.png
# /kaggle/input/brain-tumor-segmentation/images/2523.png
# /kaggle/input/brain-tumor-segmentation/images/2491.png
# /kaggle/input/brain-tumor-segmentation/images/2750.png
# /kaggle/input/brain-tumor-segmentation/images/2301.png
# /kaggle/input/brain-tumor-segmentation/images/1779.png
# /kaggle/input/brain-tumor-segmentation/images/623.png
# /kaggle/input/brain-tumor-segmentation/images/969.png
# /kaggle/input/brain-tumor-segmentation/images/2349.png
# /kaggle/input/brain-tumor-segmentation/images/1097.png
# /kaggle/input/brain-tumor-segmentation/images/642.png
# /kaggle/input/brain-tumor-segmentation/images/2558.png
# /kaggle/input/brain-tumor-segmentation/images/1401.png
# /kaggle/input/brain-tumor-segmentation/images/1594.png
# /kaggle/input/brain-tumor-segmentation/images/825.png
# /kaggle/input/brain-tumor-segmentation/images/1420.png
# /kaggle/input/brain-tumor-segmentation/images/2517.png
# /kaggle/input/brain-tumor-segmentation/images/1882.png
# /kaggle/input/brain-tumor-segmentation/images/2943.png
# /kaggle/input/brain-tumor-segmentation/images/2280.png
# /kaggle/input/brain-tumor-segmentation/images/1122.png
# /kaggle/input/brain-tumor-segmentation/images/1018.png
# /kaggle/input/brain-tumor-segmentation/images/1220.png
# /kaggle/input/brain-tumor-segmentation/images/1469.png
# /kaggle/input/brain-tumor-segmentation/images/2017.png
# /kaggle/input/brain-tumor-segmentation/images/1991.png
# /kaggle/input/brain-tumor-segmentation/images/138.png
# /kaggle/input/brain-tumor-segmentation/images/629.png
# /kaggle/input/brain-tumor-segmentation/images/2380.png
# /kaggle/input/brain-tumor-segmentation/images/2344.png
# /kaggle/input/brain-tumor-segmentation/images/2113.png
# /kaggle/input/brain-tumor-segmentation/images/1333.png
# /kaggle/input/brain-tumor-segmentation/images/2213.png
# /kaggle/input/brain-tumor-segmentation/images/396.png
# /kaggle/input/brain-tumor-segmentation/images/4.png
# /kaggle/input/brain-tumor-segmentation/images/1405.png
# /kaggle/input/brain-tumor-segmentation/images/2095.png
# /kaggle/input/brain-tumor-segmentation/images/796.png
# /kaggle/input/brain-tumor-segmentation/images/844.png
# /kaggle/input/brain-tumor-segmentation/images/225.png
# /kaggle/input/brain-tumor-segmentation/images/1371.png
# /kaggle/input/brain-tumor-segmentation/images/561.png
# /kaggle/input/brain-tumor-segmentation/images/2028.png
# /kaggle/input/brain-tumor-segmentation/images/2472.png
# /kaggle/input/brain-tumor-segmentation/images/588.png
# /kaggle/input/brain-tumor-segmentation/images/492.png
# /kaggle/input/brain-tumor-segmentation/images/2370.png
# /kaggle/input/brain-tumor-segmentation/images/2853.png
# /kaggle/input/brain-tumor-segmentation/images/2609.png
# /kaggle/input/brain-tumor-segmentation/images/669.png
# /kaggle/input/brain-tumor-segmentation/images/2037.png
# /kaggle/input/brain-tumor-segmentation/images/2173.png
# /kaggle/input/brain-tumor-segmentation/images/1315.png
# /kaggle/input/brain-tumor-segmentation/images/1868.png
# /kaggle/input/brain-tumor-segmentation/images/1219.png
# /kaggle/input/brain-tumor-segmentation/images/1887.png
# /kaggle/input/brain-tumor-segmentation/images/1482.png
# /kaggle/input/brain-tumor-segmentation/images/2534.png
# /kaggle/input/brain-tumor-segmentation/images/192.png
# /kaggle/input/brain-tumor-segmentation/images/2463.png
# /kaggle/input/brain-tumor-segmentation/images/3051.png
# /kaggle/input/brain-tumor-segmentation/images/2067.png
# /kaggle/input/brain-tumor-segmentation/images/2340.png
# /kaggle/input/brain-tumor-segmentation/images/2806.png
# /kaggle/input/brain-tumor-segmentation/images/2466.png
# /kaggle/input/brain-tumor-segmentation/images/1249.png
# /kaggle/input/brain-tumor-segmentation/images/2097.png
# /kaggle/input/brain-tumor-segmentation/images/43.png
# /kaggle/input/brain-tumor-segmentation/images/1137.png
# /kaggle/input/brain-tumor-segmentation/images/229.png
# /kaggle/input/brain-tumor-segmentation/images/1598.png
# /kaggle/input/brain-tumor-segmentation/images/992.png
# /kaggle/input/brain-tumor-segmentation/images/1783.png
# /kaggle/input/brain-tumor-segmentation/images/635.png
# /kaggle/input/brain-tumor-segmentation/images/2040.png
# /kaggle/input/brain-tumor-segmentation/images/1844.png
# /kaggle/input/brain-tumor-segmentation/images/1135.png
# /kaggle/input/brain-tumor-segmentation/images/2405.png
# /kaggle/input/brain-tumor-segmentation/images/2242.png
# /kaggle/input/brain-tumor-segmentation/images/962.png
# /kaggle/input/brain-tumor-segmentation/images/129.png
# /kaggle/input/brain-tumor-segmentation/images/1946.png
# /kaggle/input/brain-tumor-segmentation/images/331.png
# /kaggle/input/brain-tumor-segmentation/images/1885.png
# /kaggle/input/brain-tumor-segmentation/images/1243.png
# /kaggle/input/brain-tumor-segmentation/images/1067.png
# /kaggle/input/brain-tumor-segmentation/images/313.png
# /kaggle/input/brain-tumor-segmentation/images/966.png
# /kaggle/input/brain-tumor-segmentation/images/672.png
# /kaggle/input/brain-tumor-segmentation/images/2371.png
# /kaggle/input/brain-tumor-segmentation/images/820.png
# /kaggle/input/brain-tumor-segmentation/images/1558.png
# /kaggle/input/brain-tumor-segmentation/images/1349.png
# /kaggle/input/brain-tumor-segmentation/images/1279.png
# /kaggle/input/brain-tumor-segmentation/images/1733.png
# /kaggle/input/brain-tumor-segmentation/images/1740.png
# /kaggle/input/brain-tumor-segmentation/images/580.png
# /kaggle/input/brain-tumor-segmentation/images/345.png
# /kaggle/input/brain-tumor-segmentation/images/2611.png
# /kaggle/input/brain-tumor-segmentation/images/2053.png
# /kaggle/input/brain-tumor-segmentation/images/1694.png
# /kaggle/input/brain-tumor-segmentation/images/171.png
# /kaggle/input/brain-tumor-segmentation/images/682.png
# /kaggle/input/brain-tumor-segmentation/images/1113.png
# /kaggle/input/brain-tumor-segmentation/images/903.png
# /kaggle/input/brain-tumor-segmentation/images/3015.png
# /kaggle/input/brain-tumor-segmentation/images/2066.png
# /kaggle/input/brain-tumor-segmentation/images/2786.png
# /kaggle/input/brain-tumor-segmentation/images/1154.png
# /kaggle/input/brain-tumor-segmentation/images/1984.png
# /kaggle/input/brain-tumor-segmentation/images/1755.png
# /kaggle/input/brain-tumor-segmentation/images/1616.png
# /kaggle/input/brain-tumor-segmentation/images/1913.png
# /kaggle/input/brain-tumor-segmentation/images/287.png
# /kaggle/input/brain-tumor-segmentation/images/1339.png
# /kaggle/input/brain-tumor-segmentation/images/1187.png
# /kaggle/input/brain-tumor-segmentation/images/1103.png
# /kaggle/input/brain-tumor-segmentation/images/2435.png
# /kaggle/input/brain-tumor-segmentation/images/1199.png
# /kaggle/input/brain-tumor-segmentation/images/324.png
# /kaggle/input/brain-tumor-segmentation/images/145.png
# /kaggle/input/brain-tumor-segmentation/images/1255.png
# /kaggle/input/brain-tumor-segmentation/images/2864.png
# /kaggle/input/brain-tumor-segmentation/images/863.png
# /kaggle/input/brain-tumor-segmentation/images/1283.png
# /kaggle/input/brain-tumor-segmentation/images/2904.png
# /kaggle/input/brain-tumor-segmentation/images/1108.png
# /kaggle/input/brain-tumor-segmentation/images/1430.png
# /kaggle/input/brain-tumor-segmentation/images/2717.png
# /kaggle/input/brain-tumor-segmentation/images/1548.png
# /kaggle/input/brain-tumor-segmentation/images/40.png
# /kaggle/input/brain-tumor-segmentation/images/1322.png
# /kaggle/input/brain-tumor-segmentation/images/2875.png
# /kaggle/input/brain-tumor-segmentation/images/2082.png
# /kaggle/input/brain-tumor-segmentation/images/1528.png
# /kaggle/input/brain-tumor-segmentation/images/209.png
# /kaggle/input/brain-tumor-segmentation/images/2855.png
# /kaggle/input/brain-tumor-segmentation/images/2626.png
# /kaggle/input/brain-tumor-segmentation/images/1751.png
# /kaggle/input/brain-tumor-segmentation/images/197.png
# /kaggle/input/brain-tumor-segmentation/images/2544.png
# /kaggle/input/brain-tumor-segmentation/images/1874.png
# /kaggle/input/brain-tumor-segmentation/images/1970.png
# /kaggle/input/brain-tumor-segmentation/images/1240.png
# /kaggle/input/brain-tumor-segmentation/images/1130.png
# /kaggle/input/brain-tumor-segmentation/images/982.png
# /kaggle/input/brain-tumor-segmentation/images/1507.png
# /kaggle/input/brain-tumor-segmentation/images/445.png
# /kaggle/input/brain-tumor-segmentation/images/1006.png
# /kaggle/input/brain-tumor-segmentation/images/2776.png
# /kaggle/input/brain-tumor-segmentation/images/575.png
# /kaggle/input/brain-tumor-segmentation/images/311.png
# /kaggle/input/brain-tumor-segmentation/images/1347.png
# /kaggle/input/brain-tumor-segmentation/images/959.png
# /kaggle/input/brain-tumor-segmentation/images/3005.png
# /kaggle/input/brain-tumor-segmentation/images/1771.png
# /kaggle/input/brain-tumor-segmentation/images/1940.png
# /kaggle/input/brain-tumor-segmentation/images/33.png
# /kaggle/input/brain-tumor-segmentation/images/126.png
# /kaggle/input/brain-tumor-segmentation/images/876.png
# /kaggle/input/brain-tumor-segmentation/images/2761.png
# /kaggle/input/brain-tumor-segmentation/images/147.png
# /kaggle/input/brain-tumor-segmentation/images/973.png
# /kaggle/input/brain-tumor-segmentation/images/2599.png
# /kaggle/input/brain-tumor-segmentation/images/688.png
# /kaggle/input/brain-tumor-segmentation/images/1212.png
# /kaggle/input/brain-tumor-segmentation/images/1165.png
# /kaggle/input/brain-tumor-segmentation/images/2103.png
# /kaggle/input/brain-tumor-segmentation/images/468.png
# /kaggle/input/brain-tumor-segmentation/images/2816.png
# /kaggle/input/brain-tumor-segmentation/images/2250.png
# /kaggle/input/brain-tumor-segmentation/images/326.png
# /kaggle/input/brain-tumor-segmentation/images/2252.png
# /kaggle/input/brain-tumor-segmentation/images/357.png
# /kaggle/input/brain-tumor-segmentation/images/2490.png
# /kaggle/input/brain-tumor-segmentation/images/1361.png
# /kaggle/input/brain-tumor-segmentation/images/1872.png
# /kaggle/input/brain-tumor-segmentation/images/1650.png
# /kaggle/input/brain-tumor-segmentation/images/85.png
# /kaggle/input/brain-tumor-segmentation/images/9.png
# /kaggle/input/brain-tumor-segmentation/images/604.png
# /kaggle/input/brain-tumor-segmentation/images/2012.png
# /kaggle/input/brain-tumor-segmentation/images/1045.png
# /kaggle/input/brain-tumor-segmentation/images/102.png
# /kaggle/input/brain-tumor-segmentation/images/2007.png
# /kaggle/input/brain-tumor-segmentation/images/1904.png
# /kaggle/input/brain-tumor-segmentation/images/2862.png
# /kaggle/input/brain-tumor-segmentation/images/1132.png
# /kaggle/input/brain-tumor-segmentation/images/254.png
# /kaggle/input/brain-tumor-segmentation/images/2543.png
# /kaggle/input/brain-tumor-segmentation/images/673.png
# /kaggle/input/brain-tumor-segmentation/images/1338.png
# /kaggle/input/brain-tumor-segmentation/images/2796.png
# /kaggle/input/brain-tumor-segmentation/images/1230.png
# /kaggle/input/brain-tumor-segmentation/images/1055.png
# /kaggle/input/brain-tumor-segmentation/images/931.png
# /kaggle/input/brain-tumor-segmentation/images/2190.png
# /kaggle/input/brain-tumor-segmentation/images/2174.png
# /kaggle/input/brain-tumor-segmentation/images/2868.png
# /kaggle/input/brain-tumor-segmentation/images/245.png
# /kaggle/input/brain-tumor-segmentation/images/658.png
# /kaggle/input/brain-tumor-segmentation/images/2865.png
# /kaggle/input/brain-tumor-segmentation/images/431.png
# /kaggle/input/brain-tumor-segmentation/images/2593.png
# /kaggle/input/brain-tumor-segmentation/images/465.png
# /kaggle/input/brain-tumor-segmentation/images/647.png
# /kaggle/input/brain-tumor-segmentation/images/2101.png
# /kaggle/input/brain-tumor-segmentation/images/1802.png
# /kaggle/input/brain-tumor-segmentation/images/1435.png
# /kaggle/input/brain-tumor-segmentation/images/823.png
# /kaggle/input/brain-tumor-segmentation/images/1282.png
# /kaggle/input/brain-tumor-segmentation/images/2575.png
# /kaggle/input/brain-tumor-segmentation/images/1302.png
# /kaggle/input/brain-tumor-segmentation/images/891.png
# /kaggle/input/brain-tumor-segmentation/images/1953.png
# /kaggle/input/brain-tumor-segmentation/images/466.png
# /kaggle/input/brain-tumor-segmentation/images/1552.png
# /kaggle/input/brain-tumor-segmentation/images/1039.png
# /kaggle/input/brain-tumor-segmentation/images/1538.png
# /kaggle/input/brain-tumor-segmentation/images/978.png
# /kaggle/input/brain-tumor-segmentation/images/689.png
# /kaggle/input/brain-tumor-segmentation/images/168.png
# /kaggle/input/brain-tumor-segmentation/images/2150.png
# /kaggle/input/brain-tumor-segmentation/images/984.png
# /kaggle/input/brain-tumor-segmentation/images/2044.png
# /kaggle/input/brain-tumor-segmentation/images/2605.png
# /kaggle/input/brain-tumor-segmentation/images/857.png
# /kaggle/input/brain-tumor-segmentation/images/1799.png
# /kaggle/input/brain-tumor-segmentation/images/233.png
# /kaggle/input/brain-tumor-segmentation/images/2815.png
# /kaggle/input/brain-tumor-segmentation/images/2777.png
# /kaggle/input/brain-tumor-segmentation/images/2193.png
# /kaggle/input/brain-tumor-segmentation/images/2202.png
# /kaggle/input/brain-tumor-segmentation/images/2698.png
# /kaggle/input/brain-tumor-segmentation/images/2638.png
# /kaggle/input/brain-tumor-segmentation/images/200.png
# /kaggle/input/brain-tumor-segmentation/images/743.png
# /kaggle/input/brain-tumor-segmentation/images/1925.png
# /kaggle/input/brain-tumor-segmentation/images/255.png
# /kaggle/input/brain-tumor-segmentation/images/2616.png
# /kaggle/input/brain-tumor-segmentation/images/1990.png
# /kaggle/input/brain-tumor-segmentation/images/1027.png
# /kaggle/input/brain-tumor-segmentation/images/2980.png
# /kaggle/input/brain-tumor-segmentation/images/713.png
# /kaggle/input/brain-tumor-segmentation/images/3038.png
# /kaggle/input/brain-tumor-segmentation/images/284.png
# /kaggle/input/brain-tumor-segmentation/images/2358.png
# /kaggle/input/brain-tumor-segmentation/images/888.png
# /kaggle/input/brain-tumor-segmentation/images/2060.png
# /kaggle/input/brain-tumor-segmentation/images/2530.png
# /kaggle/input/brain-tumor-segmentation/images/970.png
# /kaggle/input/brain-tumor-segmentation/images/818.png
# /kaggle/input/brain-tumor-segmentation/images/2196.png
# /kaggle/input/brain-tumor-segmentation/images/2540.png
# /kaggle/input/brain-tumor-segmentation/images/1490.png
# /kaggle/input/brain-tumor-segmentation/images/2546.png
# /kaggle/input/brain-tumor-segmentation/images/2230.png
# /kaggle/input/brain-tumor-segmentation/images/1077.png
# /kaggle/input/brain-tumor-segmentation/images/1495.png
# /kaggle/input/brain-tumor-segmentation/images/1822.png
# /kaggle/input/brain-tumor-segmentation/images/2642.png
# /kaggle/input/brain-tumor-segmentation/images/546.png
# /kaggle/input/brain-tumor-segmentation/images/1447.png
# /kaggle/input/brain-tumor-segmentation/images/1884.png
# /kaggle/input/brain-tumor-segmentation/images/1025.png
# /kaggle/input/brain-tumor-segmentation/images/2335.png
# /kaggle/input/brain-tumor-segmentation/images/1423.png
# /kaggle/input/brain-tumor-segmentation/images/56.png
# /kaggle/input/brain-tumor-segmentation/images/911.png
# /kaggle/input/brain-tumor-segmentation/images/1593.png
# /kaggle/input/brain-tumor-segmentation/images/989.png
# /kaggle/input/brain-tumor-segmentation/images/1295.png
# /kaggle/input/brain-tumor-segmentation/images/2140.png
# /kaggle/input/brain-tumor-segmentation/images/2921.png
# /kaggle/input/brain-tumor-segmentation/images/515.png
# /kaggle/input/brain-tumor-segmentation/images/1402.png
# /kaggle/input/brain-tumor-segmentation/images/2071.png
# /kaggle/input/brain-tumor-segmentation/images/2172.png
# /kaggle/input/brain-tumor-segmentation/images/2483.png
# /kaggle/input/brain-tumor-segmentation/images/1324.png
# /kaggle/input/brain-tumor-segmentation/images/1107.png
# /kaggle/input/brain-tumor-segmentation/images/578.png
# /kaggle/input/brain-tumor-segmentation/images/2229.png
# /kaggle/input/brain-tumor-segmentation/images/1228.png
# /kaggle/input/brain-tumor-segmentation/images/116.png
# /kaggle/input/brain-tumor-segmentation/images/547.png
# /kaggle/input/brain-tumor-segmentation/images/1367.png
# /kaggle/input/brain-tumor-segmentation/images/2311.png
# /kaggle/input/brain-tumor-segmentation/images/2148.png
# /kaggle/input/brain-tumor-segmentation/images/555.png
# /kaggle/input/brain-tumor-segmentation/images/2467.png
# /kaggle/input/brain-tumor-segmentation/images/2843.png
# /kaggle/input/brain-tumor-segmentation/images/2613.png
# /kaggle/input/brain-tumor-segmentation/images/2144.png
# /kaggle/input/brain-tumor-segmentation/images/847.png
# /kaggle/input/brain-tumor-segmentation/images/879.png
# /kaggle/input/brain-tumor-segmentation/images/2548.png
# /kaggle/input/brain-tumor-segmentation/images/1104.png
# /kaggle/input/brain-tumor-segmentation/images/2753.png
# /kaggle/input/brain-tumor-segmentation/images/2556.png
# /kaggle/input/brain-tumor-segmentation/images/2178.png
# /kaggle/input/brain-tumor-segmentation/images/2910.png
# /kaggle/input/brain-tumor-segmentation/images/533.png
# /kaggle/input/brain-tumor-segmentation/images/853.png
# /kaggle/input/brain-tumor-segmentation/images/3003.png
# /kaggle/input/brain-tumor-segmentation/images/2356.png
# /kaggle/input/brain-tumor-segmentation/images/1818.png
# /kaggle/input/brain-tumor-segmentation/images/971.png
# /kaggle/input/brain-tumor-segmentation/images/2384.png
# /kaggle/input/brain-tumor-segmentation/images/520.png
# /kaggle/input/brain-tumor-segmentation/images/1047.png
# /kaggle/input/brain-tumor-segmentation/images/2912.png
# /kaggle/input/brain-tumor-segmentation/images/2475.png
# /kaggle/input/brain-tumor-segmentation/images/2983.png
# /kaggle/input/brain-tumor-segmentation/images/2622.png
# /kaggle/input/brain-tumor-segmentation/images/299.png
# /kaggle/input/brain-tumor-segmentation/images/3034.png
# /kaggle/input/brain-tumor-segmentation/images/1288.png
# /kaggle/input/brain-tumor-segmentation/images/1561.png
# /kaggle/input/brain-tumor-segmentation/images/2692.png
# /kaggle/input/brain-tumor-segmentation/images/2950.png
# /kaggle/input/brain-tumor-segmentation/images/2180.png
# /kaggle/input/brain-tumor-segmentation/images/1776.png
# /kaggle/input/brain-tumor-segmentation/images/488.png
# /kaggle/input/brain-tumor-segmentation/images/2794.png
# /kaggle/input/brain-tumor-segmentation/images/80.png
# /kaggle/input/brain-tumor-segmentation/images/698.png
# /kaggle/input/brain-tumor-segmentation/images/2919.png
# /kaggle/input/brain-tumor-segmentation/images/1150.png
# /kaggle/input/brain-tumor-segmentation/images/2644.png
# /kaggle/input/brain-tumor-segmentation/images/55.png
# /kaggle/input/brain-tumor-segmentation/images/1932.png
# /kaggle/input/brain-tumor-segmentation/images/1285.png
# /kaggle/input/brain-tumor-segmentation/images/1142.png
# /kaggle/input/brain-tumor-segmentation/images/2898.png
# /kaggle/input/brain-tumor-segmentation/images/378.png
# /kaggle/input/brain-tumor-segmentation/images/2955.png
# /kaggle/input/brain-tumor-segmentation/images/965.png
# /kaggle/input/brain-tumor-segmentation/images/1541.png
# /kaggle/input/brain-tumor-segmentation/images/3062.png
# /kaggle/input/brain-tumor-segmentation/images/2205.png
# /kaggle/input/brain-tumor-segmentation/images/280.png
# /kaggle/input/brain-tumor-segmentation/images/130.png
# /kaggle/input/brain-tumor-segmentation/images/592.png
# /kaggle/input/brain-tumor-segmentation/images/586.png
# /kaggle/input/brain-tumor-segmentation/images/1054.png
# /kaggle/input/brain-tumor-segmentation/images/1121.png
# /kaggle/input/brain-tumor-segmentation/images/522.png
# /kaggle/input/brain-tumor-segmentation/images/291.png
# /kaggle/input/brain-tumor-segmentation/images/443.png
# /kaggle/input/brain-tumor-segmentation/images/846.png
# /kaggle/input/brain-tumor-segmentation/images/2603.png
# /kaggle/input/brain-tumor-segmentation/images/50.png
# /kaggle/input/brain-tumor-segmentation/images/2449.png
# /kaggle/input/brain-tumor-segmentation/images/288.png
# /kaggle/input/brain-tumor-segmentation/images/307.png
# /kaggle/input/brain-tumor-segmentation/images/2446.png
# /kaggle/input/brain-tumor-segmentation/images/840.png
# /kaggle/input/brain-tumor-segmentation/images/2267.png
# /kaggle/input/brain-tumor-segmentation/images/1585.png
# /kaggle/input/brain-tumor-segmentation/images/2934.png
# /kaggle/input/brain-tumor-segmentation/images/2706.png
# /kaggle/input/brain-tumor-segmentation/images/1335.png
# /kaggle/input/brain-tumor-segmentation/images/1735.png
# /kaggle/input/brain-tumor-segmentation/images/2382.png
# /kaggle/input/brain-tumor-segmentation/images/218.png
# /kaggle/input/brain-tumor-segmentation/images/1583.png
# /kaggle/input/brain-tumor-segmentation/images/2488.png
# /kaggle/input/brain-tumor-segmentation/images/2809.png
# /kaggle/input/brain-tumor-segmentation/images/1038.png
# /kaggle/input/brain-tumor-segmentation/images/1732.png
# /kaggle/input/brain-tumor-segmentation/images/2138.png
# /kaggle/input/brain-tumor-segmentation/images/2499.png
# /kaggle/input/brain-tumor-segmentation/images/2342.png
# /kaggle/input/brain-tumor-segmentation/images/1909.png
# /kaggle/input/brain-tumor-segmentation/images/589.png
# /kaggle/input/brain-tumor-segmentation/images/607.png
# /kaggle/input/brain-tumor-segmentation/images/1078.png
# /kaggle/input/brain-tumor-segmentation/images/2364.png
# /kaggle/input/brain-tumor-segmentation/images/405.png
# /kaggle/input/brain-tumor-segmentation/images/2758.png
# /kaggle/input/brain-tumor-segmentation/images/3045.png
# /kaggle/input/brain-tumor-segmentation/images/2089.png
# /kaggle/input/brain-tumor-segmentation/images/1289.png
# /kaggle/input/brain-tumor-segmentation/images/1533.png
# /kaggle/input/brain-tumor-segmentation/images/2923.png
# /kaggle/input/brain-tumor-segmentation/images/779.png
# /kaggle/input/brain-tumor-segmentation/images/1126.png
# /kaggle/input/brain-tumor-segmentation/images/2713.png
# /kaggle/input/brain-tumor-segmentation/images/2827.png
# /kaggle/input/brain-tumor-segmentation/images/1831.png
# /kaggle/input/brain-tumor-segmentation/images/1461.png
# /kaggle/input/brain-tumor-segmentation/images/199.png
# /kaggle/input/brain-tumor-segmentation/images/2059.png
# /kaggle/input/brain-tumor-segmentation/images/1674.png
# /kaggle/input/brain-tumor-segmentation/images/849.png
# /kaggle/input/brain-tumor-segmentation/images/112.png
# /kaggle/input/brain-tumor-segmentation/images/755.png
# /kaggle/input/brain-tumor-segmentation/images/763.png
# /kaggle/input/brain-tumor-segmentation/images/1344.png
# /kaggle/input/brain-tumor-segmentation/images/2858.png
# /kaggle/input/brain-tumor-segmentation/images/2654.png
# /kaggle/input/brain-tumor-segmentation/images/1556.png
# /kaggle/input/brain-tumor-segmentation/images/1941.png
# /kaggle/input/brain-tumor-segmentation/images/788.png
# /kaggle/input/brain-tumor-segmentation/images/2916.png
# /kaggle/input/brain-tumor-segmentation/images/2756.png
# /kaggle/input/brain-tumor-segmentation/images/2672.png
# /kaggle/input/brain-tumor-segmentation/images/2598.png
# /kaggle/input/brain-tumor-segmentation/images/3042.png
# /kaggle/input/brain-tumor-segmentation/images/501.png
# /kaggle/input/brain-tumor-segmentation/images/1394.png
# /kaggle/input/brain-tumor-segmentation/images/2629.png
# /kaggle/input/brain-tumor-segmentation/images/1568.png
# /kaggle/input/brain-tumor-segmentation/images/723.png
# /kaggle/input/brain-tumor-segmentation/images/2473.png
# /kaggle/input/brain-tumor-segmentation/images/2630.png
# /kaggle/input/brain-tumor-segmentation/images/2545.png
# /kaggle/input/brain-tumor-segmentation/images/1090.png
# /kaggle/input/brain-tumor-segmentation/images/1512.png
# /kaggle/input/brain-tumor-segmentation/images/2748.png
# /kaggle/input/brain-tumor-segmentation/images/938.png
# /kaggle/input/brain-tumor-segmentation/images/49.png
# /kaggle/input/brain-tumor-segmentation/images/866.png
# /kaggle/input/brain-tumor-segmentation/images/2700.png
# /kaggle/input/brain-tumor-segmentation/images/868.png
# /kaggle/input/brain-tumor-segmentation/images/1545.png
# /kaggle/input/brain-tumor-segmentation/images/2444.png
# /kaggle/input/brain-tumor-segmentation/images/327.png
# /kaggle/input/brain-tumor-segmentation/images/599.png
# /kaggle/input/brain-tumor-segmentation/images/2911.png
# /kaggle/input/brain-tumor-segmentation/images/972.png
# /kaggle/input/brain-tumor-segmentation/images/1619.png
# /kaggle/input/brain-tumor-segmentation/images/747.png
# /kaggle/input/brain-tumor-segmentation/images/2124.png
# /kaggle/input/brain-tumor-segmentation/images/552.png
# /kaggle/input/brain-tumor-segmentation/images/1795.png
# /kaggle/input/brain-tumor-segmentation/images/1656.png
# /kaggle/input/brain-tumor-segmentation/images/1403.png
# /kaggle/input/brain-tumor-segmentation/images/1458.png
# /kaggle/input/brain-tumor-segmentation/images/1498.png
# /kaggle/input/brain-tumor-segmentation/images/1503.png
# /kaggle/input/brain-tumor-segmentation/images/2745.png
# /kaggle/input/brain-tumor-segmentation/images/268.png
# ...
# /kaggle/input/brain-tumor-segmentation/masks/27.png
# /kaggle/input/brain-tumor-segmentation/masks/1222.png
# /kaggle/input/brain-tumor-segmentation/masks/390.png
# /kaggle/input/brain-tumor-segmentation/masks/237.png
# /kaggle/input/brain-tumor-segmentation/masks/2895.png
# /kaggle/input/brain-tumor-segmentation/masks/451.png
# /kaggle/input/brain-tumor-segmentation/masks/2450.png
# /kaggle/input/brain-tumor-segmentation/masks/692.png
# /kaggle/input/brain-tumor-segmentation/masks/2503.png
# /kaggle/input/brain-tumor-segmentation/masks/2468.png
# /kaggle/input/brain-tumor-segmentation/masks/1982.png
# /kaggle/input/brain-tumor-segmentation/masks/474.png
# /kaggle/input/brain-tumor-segmentation/masks/2282.png
# /kaggle/input/brain-tumor-segmentation/masks/2126.png
# /kaggle/input/brain-tumor-segmentation/masks/292.png
# /kaggle/input/brain-tumor-segmentation/masks/2615.png
# /kaggle/input/brain-tumor-segmentation/masks/421.png
# /kaggle/input/brain-tumor-segmentation/masks/999.png
# /kaggle/input/brain-tumor-segmentation/masks/201.png
# /kaggle/input/brain-tumor-segmentation/masks/539.png
# /kaggle/input/brain-tumor-segmentation/masks/519.png
# /kaggle/input/brain-tumor-segmentation/masks/845.png
# /kaggle/input/brain-tumor-segmentation/masks/1395.png
# /kaggle/input/brain-tumor-segmentation/masks/1340.png
# /kaggle/input/brain-tumor-segmentation/masks/295.png
# /kaggle/input/brain-tumor-segmentation/masks/2275.png
# /kaggle/input/brain-tumor-segmentation/masks/394.png
# /kaggle/input/brain-tumor-segmentation/masks/2056.png
# /kaggle/input/brain-tumor-segmentation/masks/1718.png
# /kaggle/input/brain-tumor-segmentation/masks/2181.png
# /kaggle/input/brain-tumor-segmentation/masks/273.png
# /kaggle/input/brain-tumor-segmentation/masks/2251.png
# /kaggle/input/brain-tumor-segmentation/masks/269.png
# /kaggle/input/brain-tumor-segmentation/masks/1758.png
# /kaggle/input/brain-tumor-segmentation/masks/459.png
# /kaggle/input/brain-tumor-segmentation/masks/2141.png
# /kaggle/input/brain-tumor-segmentation/masks/413.png
# /kaggle/input/brain-tumor-segmentation/masks/2885.png
# /kaggle/input/brain-tumor-segmentation/masks/1058.png
# /kaggle/input/brain-tumor-segmentation/masks/1336.png
# /kaggle/input/brain-tumor-segmentation/masks/773.png
# /kaggle/input/brain-tumor-segmentation/masks/2214.png
# /kaggle/input/brain-tumor-segmentation/masks/78.png
# /kaggle/input/brain-tumor-segmentation/masks/212.png
# /kaggle/input/brain-tumor-segmentation/masks/3063.png
# /kaggle/input/brain-tumor-segmentation/masks/47.png
# /kaggle/input/brain-tumor-segmentation/masks/2639.png
# /kaggle/input/brain-tumor-segmentation/masks/786.png
# /kaggle/input/brain-tumor-segmentation/masks/1942.png
# /kaggle/input/brain-tumor-segmentation/masks/1797.png
# /kaggle/input/brain-tumor-segmentation/masks/2357.png
# /kaggle/input/brain-tumor-segmentation/masks/2457.png
# /kaggle/input/brain-tumor-segmentation/masks/1210.png
# /kaggle/input/brain-tumor-segmentation/masks/207.png
# /kaggle/input/brain-tumor-segmentation/masks/1110.png
# /kaggle/input/brain-tumor-segmentation/masks/1487.png
# /kaggle/input/brain-tumor-segmentation/masks/149.png
# /kaggle/input/brain-tumor-segmentation/masks/2604.png
# /kaggle/input/brain-tumor-segmentation/masks/2215.png
# /kaggle/input/brain-tumor-segmentation/masks/1805.png
# /kaggle/input/brain-tumor-segmentation/masks/487.png
# /kaggle/input/brain-tumor-segmentation/masks/1792.png
# /kaggle/input/brain-tumor-segmentation/masks/2498.png
# /kaggle/input/brain-tumor-segmentation/masks/1786.png
# /kaggle/input/brain-tumor-segmentation/masks/812.png
# /kaggle/input/brain-tumor-segmentation/masks/13.png
# /kaggle/input/brain-tumor-segmentation/masks/842.png
# /kaggle/input/brain-tumor-segmentation/masks/1691.png
# /kaggle/input/brain-tumor-segmentation/masks/2412.png
# /kaggle/input/brain-tumor-segmentation/masks/2601.png
# /kaggle/input/brain-tumor-segmentation/masks/2917.png
# /kaggle/input/brain-tumor-segmentation/masks/1974.png
# /kaggle/input/brain-tumor-segmentation/masks/2962.png
# /kaggle/input/brain-tumor-segmentation/masks/2528.png
# /kaggle/input/brain-tumor-segmentation/masks/2018.png
# /kaggle/input/brain-tumor-segmentation/masks/1571.png
# /kaggle/input/brain-tumor-segmentation/masks/974.png
# /kaggle/input/brain-tumor-segmentation/masks/1853.png
# /kaggle/input/brain-tumor-segmentation/masks/535.png
# /kaggle/input/brain-tumor-segmentation/masks/2188.png
# /kaggle/input/brain-tumor-segmentation/masks/843.png
# /kaggle/input/brain-tumor-segmentation/masks/2562.png
# /kaggle/input/brain-tumor-segmentation/masks/260.png
# /kaggle/input/brain-tumor-segmentation/masks/2527.png
# /kaggle/input/brain-tumor-segmentation/masks/2271.png
# /kaggle/input/brain-tumor-segmentation/masks/2032.png
# /kaggle/input/brain-tumor-segmentation/masks/830.png
# /kaggle/input/brain-tumor-segmentation/masks/253.png
# /kaggle/input/brain-tumor-segmentation/masks/206.png
# /kaggle/input/brain-tumor-segmentation/masks/1034.png
# /kaggle/input/brain-tumor-segmentation/masks/1834.png
# /kaggle/input/brain-tumor-segmentation/masks/2849.png
# /kaggle/input/brain-tumor-segmentation/masks/789.png
# /kaggle/input/brain-tumor-segmentation/masks/1894.png
# /kaggle/input/brain-tumor-segmentation/masks/2643.png
# /kaggle/input/brain-tumor-segmentation/masks/1365.png
# /kaggle/input/brain-tumor-segmentation/masks/557.png
# /kaggle/input/brain-tumor-segmentation/masks/2167.png
# /kaggle/input/brain-tumor-segmentation/masks/1274.png
# /kaggle/input/brain-tumor-segmentation/masks/2163.png
# /kaggle/input/brain-tumor-segmentation/masks/980.png
# /kaggle/input/brain-tumor-segmentation/masks/1309.png
# /kaggle/input/brain-tumor-segmentation/masks/1175.png
# /kaggle/input/brain-tumor-segmentation/masks/2985.png
# /kaggle/input/brain-tumor-segmentation/masks/613.png
# /kaggle/input/brain-tumor-segmentation/masks/600.png
# /kaggle/input/brain-tumor-segmentation/masks/874.png
# /kaggle/input/brain-tumor-segmentation/masks/2583.png
# /kaggle/input/brain-tumor-segmentation/masks/381.png
# /kaggle/input/brain-tumor-segmentation/masks/342.png
# /kaggle/input/brain-tumor-segmentation/masks/1252.png
# /kaggle/input/brain-tumor-segmentation/masks/1074.png
# /kaggle/input/brain-tumor-segmentation/masks/2458.png
# /kaggle/input/brain-tumor-segmentation/masks/1267.png
# /kaggle/input/brain-tumor-segmentation/masks/1866.png
# /kaggle/input/brain-tumor-segmentation/masks/2225.png
# /kaggle/input/brain-tumor-segmentation/masks/346.png
# /kaggle/input/brain-tumor-segmentation/masks/1497.png
# /kaggle/input/brain-tumor-segmentation/masks/2881.png
# /kaggle/input/brain-tumor-segmentation/masks/2939.png
# /kaggle/input/brain-tumor-segmentation/masks/134.png
# /kaggle/input/brain-tumor-segmentation/masks/721.png
# /kaggle/input/brain-tumor-segmentation/masks/898.png
# /kaggle/input/brain-tumor-segmentation/masks/1124.png
# /kaggle/input/brain-tumor-segmentation/masks/2258.png
# /kaggle/input/brain-tumor-segmentation/masks/2399.png
# /kaggle/input/brain-tumor-segmentation/masks/2288.png
# /kaggle/input/brain-tumor-segmentation/masks/1912.png
# /kaggle/input/brain-tumor-segmentation/masks/1938.png
# /kaggle/input/brain-tumor-segmentation/masks/1781.png
# /kaggle/input/brain-tumor-segmentation/masks/2227.png
# /kaggle/input/brain-tumor-segmentation/masks/2246.png
# /kaggle/input/brain-tumor-segmentation/masks/694.png
# /kaggle/input/brain-tumor-segmentation/masks/2734.png
# /kaggle/input/brain-tumor-segmentation/masks/590.png
# /kaggle/input/brain-tumor-segmentation/masks/2504.png
# /kaggle/input/brain-tumor-segmentation/masks/2972.png
# /kaggle/input/brain-tumor-segmentation/masks/1172.png
# /kaggle/input/brain-tumor-segmentation/masks/566.png
# /kaggle/input/brain-tumor-segmentation/masks/2837.png
# /kaggle/input/brain-tumor-segmentation/masks/921.png
# /kaggle/input/brain-tumor-segmentation/masks/1426.png
# /kaggle/input/brain-tumor-segmentation/masks/1957.png
# /kaggle/input/brain-tumor-segmentation/masks/1765.png
# /kaggle/input/brain-tumor-segmentation/masks/1762.png
# /kaggle/input/brain-tumor-segmentation/masks/259.png
# /kaggle/input/brain-tumor-segmentation/masks/2159.png
# /kaggle/input/brain-tumor-segmentation/masks/1889.png
# /kaggle/input/brain-tumor-segmentation/masks/1579.png
# /kaggle/input/brain-tumor-segmentation/masks/2442.png
# /kaggle/input/brain-tumor-segmentation/masks/25.png
# /kaggle/input/brain-tumor-segmentation/masks/871.png
# /kaggle/input/brain-tumor-segmentation/masks/1613.png
# /kaggle/input/brain-tumor-segmentation/masks/285.png
# /kaggle/input/brain-tumor-segmentation/masks/1297.png
# /kaggle/input/brain-tumor-segmentation/masks/341.png
# /kaggle/input/brain-tumor-segmentation/masks/54.png
# /kaggle/input/brain-tumor-segmentation/masks/1160.png
# /kaggle/input/brain-tumor-segmentation/masks/462.png
# /kaggle/input/brain-tumor-segmentation/masks/851.png
# /kaggle/input/brain-tumor-segmentation/masks/558.png
# /kaggle/input/brain-tumor-segmentation/masks/1861.png
# /kaggle/input/brain-tumor-segmentation/masks/1350.png
# /kaggle/input/brain-tumor-segmentation/masks/111.png
# /kaggle/input/brain-tumor-segmentation/masks/611.png
# /kaggle/input/brain-tumor-segmentation/masks/2055.png
# /kaggle/input/brain-tumor-segmentation/masks/2618.png
# /kaggle/input/brain-tumor-segmentation/masks/1644.png
# /kaggle/input/brain-tumor-segmentation/masks/1825.png
# /kaggle/input/brain-tumor-segmentation/masks/887.png
# /kaggle/input/brain-tumor-segmentation/masks/2586.png
# /kaggle/input/brain-tumor-segmentation/masks/2035.png
# /kaggle/input/brain-tumor-segmentation/masks/62.png
# /kaggle/input/brain-tumor-segmentation/masks/2474.png
# /kaggle/input/brain-tumor-segmentation/masks/205.png
# /kaggle/input/brain-tumor-segmentation/masks/1373.png
# /kaggle/input/brain-tumor-segmentation/masks/1265.png
# /kaggle/input/brain-tumor-segmentation/masks/699.png
# /kaggle/input/brain-tumor-segmentation/masks/2414.png
# /kaggle/input/brain-tumor-segmentation/masks/1711.png
# /kaggle/input/brain-tumor-segmentation/masks/369.png
# /kaggle/input/brain-tumor-segmentation/masks/750.png
# /kaggle/input/brain-tumor-segmentation/masks/1262.png
# /kaggle/input/brain-tumor-segmentation/masks/2610.png
# /kaggle/input/brain-tumor-segmentation/masks/2033.png
# /kaggle/input/brain-tumor-segmentation/masks/963.png
# /kaggle/input/brain-tumor-segmentation/masks/141.png
# /kaggle/input/brain-tumor-segmentation/masks/693.png
# /kaggle/input/brain-tumor-segmentation/masks/2232.png
# /kaggle/input/brain-tumor-segmentation/masks/2361.png
# /kaggle/input/brain-tumor-segmentation/masks/532.png
# /kaggle/input/brain-tumor-segmentation/masks/1408.png
# /kaggle/input/brain-tumor-segmentation/masks/309.png
# /kaggle/input/brain-tumor-segmentation/masks/560.png
# /kaggle/input/brain-tumor-segmentation/masks/1211.png
# /kaggle/input/brain-tumor-segmentation/masks/19.png
# /kaggle/input/brain-tumor-segmentation/masks/110.png
# /kaggle/input/brain-tumor-segmentation/masks/544.png
# /kaggle/input/brain-tumor-segmentation/masks/308.png
# /kaggle/input/brain-tumor-segmentation/masks/2161.png
# /kaggle/input/brain-tumor-segmentation/masks/2831.png
# /kaggle/input/brain-tumor-segmentation/masks/1988.png
# /kaggle/input/brain-tumor-segmentation/masks/2078.png
# /kaggle/input/brain-tumor-segmentation/masks/1659.png
# /kaggle/input/brain-tumor-segmentation/masks/2422.png
# /kaggle/input/brain-tumor-segmentation/masks/1911.png
# /kaggle/input/brain-tumor-segmentation/masks/1998.png
# /kaggle/input/brain-tumor-segmentation/masks/2339.png
# /kaggle/input/brain-tumor-segmentation/masks/26.png
# /kaggle/input/brain-tumor-segmentation/masks/2073.png
# /kaggle/input/brain-tumor-segmentation/masks/568.png
# /kaggle/input/brain-tumor-segmentation/masks/1960.png
# /kaggle/input/brain-tumor-segmentation/masks/2677.png
# /kaggle/input/brain-tumor-segmentation/masks/918.png
# /kaggle/input/brain-tumor-segmentation/masks/2004.png
# /kaggle/input/brain-tumor-segmentation/masks/388.png
# /kaggle/input/brain-tumor-segmentation/masks/1916.png
# /kaggle/input/brain-tumor-segmentation/masks/2739.png
# /kaggle/input/brain-tumor-segmentation/masks/1453.png
# /kaggle/input/brain-tumor-segmentation/masks/2725.png
# /kaggle/input/brain-tumor-segmentation/masks/79.png
# /kaggle/input/brain-tumor-segmentation/masks/633.png
# /kaggle/input/brain-tumor-segmentation/masks/3004.png
# /kaggle/input/brain-tumor-segmentation/masks/824.png
# /kaggle/input/brain-tumor-segmentation/masks/1396.png
# /kaggle/input/brain-tumor-segmentation/masks/2764.png
# /kaggle/input/brain-tumor-segmentation/masks/2027.png
# /kaggle/input/brain-tumor-segmentation/masks/2016.png
# /kaggle/input/brain-tumor-segmentation/masks/1609.png
# /kaggle/input/brain-tumor-segmentation/masks/2632.png
# /kaggle/input/brain-tumor-segmentation/masks/729.png
# /kaggle/input/brain-tumor-segmentation/masks/2852.png
# /kaggle/input/brain-tumor-segmentation/masks/2804.png
# /kaggle/input/brain-tumor-segmentation/masks/1414.png
# /kaggle/input/brain-tumor-segmentation/masks/1477.png
# /kaggle/input/brain-tumor-segmentation/masks/883.png
# /kaggle/input/brain-tumor-segmentation/masks/2621.png
# /kaggle/input/brain-tumor-segmentation/masks/1709.png
# /kaggle/input/brain-tumor-segmentation/masks/257.png
# /kaggle/input/brain-tumor-segmentation/masks/2766.png
# /kaggle/input/brain-tumor-segmentation/masks/2915.png
# /kaggle/input/brain-tumor-segmentation/masks/2663.png
# /kaggle/input/brain-tumor-segmentation/masks/2139.png
# /kaggle/input/brain-tumor-segmentation/masks/993.png
# /kaggle/input/brain-tumor-segmentation/masks/1281.png
# /kaggle/input/brain-tumor-segmentation/masks/305.png
# /kaggle/input/brain-tumor-segmentation/masks/2293.png
# /kaggle/input/brain-tumor-segmentation/masks/2894.png
# /kaggle/input/brain-tumor-segmentation/masks/1676.png
# /kaggle/input/brain-tumor-segmentation/masks/477.png
# /kaggle/input/brain-tumor-segmentation/masks/42.png
# /kaggle/input/brain-tumor-segmentation/masks/175.png
# /kaggle/input/brain-tumor-segmentation/masks/1261.png
# /kaggle/input/brain-tumor-segmentation/masks/1621.png
# /kaggle/input/brain-tumor-segmentation/masks/961.png
# /kaggle/input/brain-tumor-segmentation/masks/1551.png
# /kaggle/input/brain-tumor-segmentation/masks/518.png
# /kaggle/input/brain-tumor-segmentation/masks/3050.png
# /kaggle/input/brain-tumor-segmentation/masks/2155.png
# /kaggle/input/brain-tumor-segmentation/masks/1602.png
# /kaggle/input/brain-tumor-segmentation/masks/2918.png
# /kaggle/input/brain-tumor-segmentation/masks/957.png
# /kaggle/input/brain-tumor-segmentation/masks/1876.png
# /kaggle/input/brain-tumor-segmentation/masks/226.png
# /kaggle/input/brain-tumor-segmentation/masks/1493.png
# /kaggle/input/brain-tumor-segmentation/masks/2879.png
# /kaggle/input/brain-tumor-segmentation/masks/2179.png
# /kaggle/input/brain-tumor-segmentation/masks/2570.png
# /kaggle/input/brain-tumor-segmentation/masks/428.png
# /kaggle/input/brain-tumor-segmentation/masks/2927.png
# /kaggle/input/brain-tumor-segmentation/masks/2264.png
# /kaggle/input/brain-tumor-segmentation/masks/217.png
# /kaggle/input/brain-tumor-segmentation/masks/2964.png
# /kaggle/input/brain-tumor-segmentation/masks/1424.png
# /kaggle/input/brain-tumor-segmentation/masks/1710.png
# /kaggle/input/brain-tumor-segmentation/masks/2652.png
# /kaggle/input/brain-tumor-segmentation/masks/3029.png
# /kaggle/input/brain-tumor-segmentation/masks/1330.png
# /kaggle/input/brain-tumor-segmentation/masks/2708.png
# /kaggle/input/brain-tumor-segmentation/masks/867.png
# /kaggle/input/brain-tumor-segmentation/masks/2693.png
# /kaggle/input/brain-tumor-segmentation/masks/821.png
# /kaggle/input/brain-tumor-segmentation/masks/494.png
# /kaggle/input/brain-tumor-segmentation/masks/2383.png
# /kaggle/input/brain-tumor-segmentation/masks/837.png
# /kaggle/input/brain-tumor-segmentation/masks/659.png
# /kaggle/input/brain-tumor-segmentation/masks/2210.png
# /kaggle/input/brain-tumor-segmentation/masks/418.png
# /kaggle/input/brain-tumor-segmentation/masks/452.png
# /kaggle/input/brain-tumor-segmentation/masks/2627.png
# /kaggle/input/brain-tumor-segmentation/masks/981.png
# /kaggle/input/brain-tumor-segmentation/masks/948.png
# /kaggle/input/brain-tumor-segmentation/masks/2392.png
# /kaggle/input/brain-tumor-segmentation/masks/306.png
# /kaggle/input/brain-tumor-segmentation/masks/497.png
# /kaggle/input/brain-tumor-segmentation/masks/2995.png
# /kaggle/input/brain-tumor-segmentation/masks/304.png
# /kaggle/input/unet/keras/default/1/unet.py

# %%
import shutil
import sys

# Copy the file to working directory
shutil.copy("/kaggle/input/unet/keras/default/1/unet.py", "/kaggle/working/")

# Add the working directory to sys path
sys.path.append("/kaggle/working/")

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
import numpy as np
import os
from unet import unet
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2" # tf log messages suppression
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# Global parameters
H = 256
W = 256

# %%
# Metrics
def dice_coefficient(y_true, y_pred, smooth=1e-15):
    """
    Compute the Dice Coefficient for image segmentation tasks.
    
    Args:
        y_true (tensor): Ground truth mask.
        y_pred (tensor): Predicted mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        tensor: Dice coefficient score.
    """
    # Flatten the tensors
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    
    # Compute the intersection
    intersection = tf.reduce_sum(y_true * y_pred)
    
    # Compute the Dice coefficient
    dice = (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    
    return dice

def dice_loss(y_true, y_pred):
    """
    Compute the Dice Loss, which is 1 - Dice Coefficient.
    
    Args:
        y_true (tensor): Ground truth mask.
        y_pred (tensor): Predicted mask.
    
    Returns:
        tensor: Dice loss value.
    """
    return 1.0 - dice_coefficient(y_true, y_pred)

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.2): # 60% for training, 20% for validation, 20% for testing
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks", "*.png")))
    #print(images[0], masks[0])

    split_size = int(len(images) * split)

    # x refers to images and y refers to masks
    train_x, valid_x = train_test_split(images, test_size = split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size = split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size = split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size = split_size, random_state=42)

    return(train_x, train_y), (valid_x, valid_y), (test_x, test_y)
    # 60% for training, 20% for validation, 20% for testing

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0 # normalization with max pixel range
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x / 255.0 # normalization with max pixel range - white part of the mask becomes 1 instead of 255.0
    x = x.astype(np.float32) # (h, w)
    x = np.expand_dims(x, axis=-1) # (h, w, 1)
    return x

def tf_parse(x, y): # takes single image path and single mask path
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2): # X is a list of image file paths (and Y is list of mask paths)
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset
                         
if __name__ == "__main__":
    # Seeding
    np.random.seed(42)
    tf.random.set_seed(42)

    # Directory for storing files
    create_dir("files")

    # Hyperparameters
    batch_size = 16
    lr = 1e-4
    num_epochs = 60
    model_path = os.path.join("files", "model.keras")
    csv_path = os.path.join("files", "log.csv")

    # Dataset
    dataset_path = "/kaggle/input/brain-tumor-segmentation"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    #for x, y in train_dataset:
        #print(x.shape, y.shape)

    # Model
    model = unet((H,W, 3))
    model.compile(loss = dice_loss, optimizer = Adam(lr), metrics = [dice_coefficient])

    callbacks = [
        ModelCheckpoint(model_path, save_best_only=True, verbose=1),
        CSVLogger(csv_path),
        ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs = num_epochs,
        validation_data = valid_dataset,
        callbacks = callbacks
        )
# Out:
# Epoch 1/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - dice_coefficient: 0.0861 - loss: 0.9139
# Epoch 1: val_loss improved from inf to 0.96485, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 103s 491ms/step - dice_coefficient: 0.0865 - loss: 0.9135 - val_dice_coefficient: 0.0351 - val_loss: 0.9649 - learning_rate: 1.0000e-04
# Epoch 2/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - dice_coefficient: 0.2227 - loss: 0.7773
# Epoch 2: val_loss did not improve from 0.96485
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 407ms/step - dice_coefficient: 0.2228 - loss: 0.7772 - val_dice_coefficient: 0.0104 - val_loss: 0.9895 - learning_rate: 1.0000e-04
# Epoch 3/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.3054 - loss: 0.6946
# Epoch 3: val_loss did not improve from 0.96485
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.3056 - loss: 0.6944 - val_dice_coefficient: 0.0320 - val_loss: 0.9678 - learning_rate: 1.0000e-04
# Epoch 4/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.3886 - loss: 0.6114
# Epoch 4: val_loss did not improve from 0.96485
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.3887 - loss: 0.6113 - val_dice_coefficient: 0.0293 - val_loss: 0.9706 - learning_rate: 1.0000e-04
# Epoch 5/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.4758 - loss: 0.5242
# Epoch 5: val_loss improved from 0.96485 to 0.72973, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.4759 - loss: 0.5241 - val_dice_coefficient: 0.2699 - val_loss: 0.7297 - learning_rate: 1.0000e-04
# Epoch 6/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.5486 - loss: 0.4514
# Epoch 6: val_loss improved from 0.72973 to 0.51793, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.5487 - loss: 0.4513 - val_dice_coefficient: 0.4817 - val_loss: 0.5179 - learning_rate: 1.0000e-04
# Epoch 7/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.5959 - loss: 0.4041
# Epoch 7: val_loss improved from 0.51793 to 0.44451, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.5960 - loss: 0.4040 - val_dice_coefficient: 0.5558 - val_loss: 0.4445 - learning_rate: 1.0000e-04
# Epoch 8/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.6554 - loss: 0.3446
# Epoch 8: val_loss improved from 0.44451 to 0.40729, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.6554 - loss: 0.3446 - val_dice_coefficient: 0.5917 - val_loss: 0.4073 - learning_rate: 1.0000e-04
# Epoch 9/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.6983 - loss: 0.3017
# Epoch 9: val_loss did not improve from 0.40729
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.6984 - loss: 0.3016 - val_dice_coefficient: 0.3672 - val_loss: 0.6306 - learning_rate: 1.0000e-04
# Epoch 10/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.7248 - loss: 0.2752
# Epoch 10: val_loss improved from 0.40729 to 0.31853, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 423ms/step - dice_coefficient: 0.7249 - loss: 0.2751 - val_dice_coefficient: 0.6801 - val_loss: 0.3185 - learning_rate: 1.0000e-04
# Epoch 11/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.7508 - loss: 0.2492
# Epoch 11: val_loss did not improve from 0.31853
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.7508 - loss: 0.2492 - val_dice_coefficient: 0.4901 - val_loss: 0.5031 - learning_rate: 1.0000e-04
# Epoch 12/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.7778 - loss: 0.2222
# Epoch 12: val_loss improved from 0.31853 to 0.28718, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.7778 - loss: 0.2222 - val_dice_coefficient: 0.7102 - val_loss: 0.2872 - learning_rate: 1.0000e-04
# Epoch 13/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.7894 - loss: 0.2106
# Epoch 13: val_loss did not improve from 0.28718
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.7894 - loss: 0.2106 - val_dice_coefficient: 0.6806 - val_loss: 0.3166 - learning_rate: 1.0000e-04
# Epoch 14/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8037 - loss: 0.1963
# Epoch 14: val_loss did not improve from 0.28718
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8038 - loss: 0.1962 - val_dice_coefficient: 0.6751 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 15/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.7890 - loss: 0.2110
# Epoch 15: val_loss improved from 0.28718 to 0.26435, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.7890 - loss: 0.2110 - val_dice_coefficient: 0.7340 - val_loss: 0.2644 - learning_rate: 1.0000e-04
# Epoch 16/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8228 - loss: 0.1772
# Epoch 16: val_loss did not improve from 0.26435
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8227 - loss: 0.1773 - val_dice_coefficient: 0.7248 - val_loss: 0.2740 - learning_rate: 1.0000e-04
# Epoch 17/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8311 - loss: 0.1689
# Epoch 17: val_loss did not improve from 0.26435
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8311 - loss: 0.1689 - val_dice_coefficient: 0.7259 - val_loss: 0.2748 - learning_rate: 1.0000e-04
# Epoch 18/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8497 - loss: 0.1503
# Epoch 18: val_loss improved from 0.26435 to 0.24615, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 424ms/step - dice_coefficient: 0.8497 - loss: 0.1503 - val_dice_coefficient: 0.7533 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 19/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8662 - loss: 0.1338
# Epoch 19: val_loss improved from 0.24615 to 0.21370, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.8662 - loss: 0.1338 - val_dice_coefficient: 0.7859 - val_loss: 0.2137 - learning_rate: 1.0000e-04
# Epoch 20/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8741 - loss: 0.1259
# Epoch 20: val_loss did not improve from 0.21370
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8741 - loss: 0.1259 - val_dice_coefficient: 0.7694 - val_loss: 0.2291 - learning_rate: 1.0000e-04
# Epoch 21/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8828 - loss: 0.1172
# Epoch 21: val_loss did not improve from 0.21370
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.8828 - loss: 0.1172 - val_dice_coefficient: 0.7556 - val_loss: 0.2432 - learning_rate: 1.0000e-04
# Epoch 22/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8792 - loss: 0.1208
# Epoch 22: val_loss did not improve from 0.21370
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8792 - loss: 0.1208 - val_dice_coefficient: 0.7830 - val_loss: 0.2154 - learning_rate: 1.0000e-04
# Epoch 23/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8916 - loss: 0.1084
# Epoch 23: val_loss did not improve from 0.21370
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8916 - loss: 0.1084 - val_dice_coefficient: 0.7716 - val_loss: 0.2276 - learning_rate: 1.0000e-04
# Epoch 24/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8819 - loss: 0.1181
# Epoch 24: val_loss improved from 0.21370 to 0.21159, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.8819 - loss: 0.1181 - val_dice_coefficient: 0.7888 - val_loss: 0.2116 - learning_rate: 1.0000e-04
# Epoch 25/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8957 - loss: 0.1043
# Epoch 25: val_loss did not improve from 0.21159
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 411ms/step - dice_coefficient: 0.8956 - loss: 0.1044 - val_dice_coefficient: 0.7770 - val_loss: 0.2253 - learning_rate: 1.0000e-04
# Epoch 26/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8972 - loss: 0.1028
# Epoch 26: val_loss did not improve from 0.21159
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.8972 - loss: 0.1028 - val_dice_coefficient: 0.7768 - val_loss: 0.2236 - learning_rate: 1.0000e-04
# Epoch 27/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.8999 - loss: 0.1001
# Epoch 27: val_loss improved from 0.21159 to 0.20335, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.8999 - loss: 0.1001 - val_dice_coefficient: 0.7966 - val_loss: 0.2033 - learning_rate: 1.0000e-04
# Epoch 28/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9075 - loss: 0.0925
# Epoch 28: val_loss did not improve from 0.20335
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9075 - loss: 0.0925 - val_dice_coefficient: 0.7930 - val_loss: 0.2067 - learning_rate: 1.0000e-04
# Epoch 29/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9091 - loss: 0.0909
# Epoch 29: val_loss improved from 0.20335 to 0.19187, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.9091 - loss: 0.0909 - val_dice_coefficient: 0.8084 - val_loss: 0.1919 - learning_rate: 1.0000e-04
# Epoch 30/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9149 - loss: 0.0851
# Epoch 30: val_loss did not improve from 0.19187
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9149 - loss: 0.0851 - val_dice_coefficient: 0.8023 - val_loss: 0.1965 - learning_rate: 1.0000e-04
# Epoch 31/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9172 - loss: 0.0828
# Epoch 31: val_loss did not improve from 0.19187
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9172 - loss: 0.0828 - val_dice_coefficient: 0.8034 - val_loss: 0.1964 - learning_rate: 1.0000e-04
# Epoch 32/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9218 - loss: 0.0782
# Epoch 32: val_loss improved from 0.19187 to 0.18252, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.9218 - loss: 0.0782 - val_dice_coefficient: 0.8179 - val_loss: 0.1825 - learning_rate: 1.0000e-04
# Epoch 33/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9236 - loss: 0.0764
# Epoch 33: val_loss did not improve from 0.18252
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9236 - loss: 0.0764 - val_dice_coefficient: 0.8173 - val_loss: 0.1835 - learning_rate: 1.0000e-04
# Epoch 34/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9188 - loss: 0.0812
# Epoch 34: val_loss did not improve from 0.18252
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9188 - loss: 0.0812 - val_dice_coefficient: 0.7739 - val_loss: 0.2229 - learning_rate: 1.0000e-04
# Epoch 35/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9119 - loss: 0.0881
# Epoch 35: val_loss did not improve from 0.18252
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9118 - loss: 0.0882 - val_dice_coefficient: 0.7977 - val_loss: 0.2031 - learning_rate: 1.0000e-04
# Epoch 36/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9099 - loss: 0.0901
# Epoch 36: val_loss did not improve from 0.18252
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9099 - loss: 0.0901 - val_dice_coefficient: 0.7414 - val_loss: 0.2577 - learning_rate: 1.0000e-04
# Epoch 37/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9171 - loss: 0.0829
# Epoch 37: val_loss did not improve from 0.18252
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9172 - loss: 0.0828 - val_dice_coefficient: 0.7961 - val_loss: 0.2025 - learning_rate: 1.0000e-04
# Epoch 38/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9277 - loss: 0.0723
# Epoch 38: val_loss improved from 0.18252 to 0.17748, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.9278 - loss: 0.0722 - val_dice_coefficient: 0.8216 - val_loss: 0.1775 - learning_rate: 1.0000e-05
# Epoch 39/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9350 - loss: 0.0650
# Epoch 39: val_loss improved from 0.17748 to 0.17739, saving model to files/model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - dice_coefficient: 0.9350 - loss: 0.0650 - val_dice_coefficient: 0.8218 - val_loss: 0.1774 - learning_rate: 1.0000e-05
# Epoch 40/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9371 - loss: 0.0629
# Epoch 40: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9371 - loss: 0.0629 - val_dice_coefficient: 0.8209 - val_loss: 0.1783 - learning_rate: 1.0000e-05
# Epoch 41/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9387 - loss: 0.0613
# Epoch 41: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9388 - loss: 0.0612 - val_dice_coefficient: 0.8202 - val_loss: 0.1791 - learning_rate: 1.0000e-05
# Epoch 42/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9401 - loss: 0.0599
# Epoch 42: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9401 - loss: 0.0599 - val_dice_coefficient: 0.8194 - val_loss: 0.1798 - learning_rate: 1.0000e-05
# Epoch 43/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9413 - loss: 0.0587
# Epoch 43: val_loss did not improve from 0.17739
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9413 - loss: 0.0587 - val_dice_coefficient: 0.8182 - val_loss: 0.1810 - learning_rate: 1.0000e-05
# Epoch 44/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9425 - loss: 0.0575
# Epoch 44: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9425 - loss: 0.0575 - val_dice_coefficient: 0.8168 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 45/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9426 - loss: 0.0574
# Epoch 45: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9426 - loss: 0.0574 - val_dice_coefficient: 0.8171 - val_loss: 0.1820 - learning_rate: 1.0000e-06
# Epoch 46/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9428 - loss: 0.0572
# Epoch 46: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9428 - loss: 0.0572 - val_dice_coefficient: 0.8171 - val_loss: 0.1820 - learning_rate: 1.0000e-06
# Epoch 47/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9430 - loss: 0.0570
# Epoch 47: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9430 - loss: 0.0570 - val_dice_coefficient: 0.8170 - val_loss: 0.1821 - learning_rate: 1.0000e-06
# Epoch 48/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9432 - loss: 0.0568
# Epoch 48: val_loss did not improve from 0.17739
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-07.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9432 - loss: 0.0568 - val_dice_coefficient: 0.8169 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 49/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9433 - loss: 0.0567
# Epoch 49: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9433 - loss: 0.0567 - val_dice_coefficient: 0.8171 - val_loss: 0.1820 - learning_rate: 1.0000e-07
# Epoch 50/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9434 - loss: 0.0566
# Epoch 50: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9434 - loss: 0.0566 - val_dice_coefficient: 0.8172 - val_loss: 0.1819 - learning_rate: 1.0000e-07
# Epoch 51/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9434 - loss: 0.0566
# Epoch 51: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9434 - loss: 0.0566 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 52/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9434 - loss: 0.0566
# Epoch 52: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9434 - loss: 0.0566 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 53/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9435 - loss: 0.0565
# Epoch 53: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9435 - loss: 0.0565 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 54/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9435 - loss: 0.0565
# Epoch 54: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9435 - loss: 0.0565 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 55/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9435 - loss: 0.0565
# Epoch 55: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 409ms/step - dice_coefficient: 0.9435 - loss: 0.0565 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 56/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9435 - loss: 0.0565
# Epoch 56: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9435 - loss: 0.0565 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 57/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9436 - loss: 0.0564
# Epoch 57: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9436 - loss: 0.0564 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 58/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9436 - loss: 0.0564
# Epoch 58: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9436 - loss: 0.0564 - val_dice_coefficient: 0.8173 - val_loss: 0.1818 - learning_rate: 1.0000e-07
# Epoch 59/60
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - dice_coefficient: 0.9436 - loss: 0.0564
# Epoch 59: val_loss did not improve from 0.17739
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - dice_coefficient: 0.9436 - loss: 0.0564 - val_dice_coefficient: 0.8173 - val_loss: 0.1819 - learning_rate: 1.0000e-07

# %%
from IPython.display import FileLink

FileLink("/kaggle/working/files/log.csv")
# Out:
# /kaggle/working/files/log.csv
